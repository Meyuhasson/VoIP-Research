# %% [markdown]
# # imports

# %%
import pandas as pd

# %% [markdown]
# # load data

# %%
mal_pcap1 = r"C:\Users\edenm\Documents\GitHub\VoIP-Research\Data\proccesed and tagged external datasets\RTP Flood records\malicious recordings\RTP_A_Host_Attacker\rtp.0.0.csv"
mal_pcap2 = r"C:\Users\edenm\Documents\GitHub\VoIP-Research\Data\proccesed and tagged external datasets\RTP Flood records\malicious recordings\RTP_B_Host_Attacker\rtp.0.1.csv"

# %%
mal_pcap1 = pd.read_csv(mal_pcap1)
mal_pcap2 = pd.read_csv(mal_pcap2)

# %%
mal_pcap1
# Out:
#        No.        Time        Source  Destination Protocol  Length  Info
# 0        1    0.000000  172.168.1.44  10.10.10.22      UDP     214   NaN
# 1        2    0.020216  172.168.1.44  10.10.10.22      UDP     214   NaN
# 2        3    0.040524  172.168.1.44  10.10.10.22      UDP     214   NaN
# 3        4    0.060748  172.168.1.44  10.10.10.22      UDP     214   NaN
# 4        5    0.080975  172.168.1.44  10.10.10.22      UDP     214   NaN
# ...    ...         ...           ...          ...      ...     ...   ...
# 9990  9991  201.623152  172.168.1.44  10.10.10.22      UDP     214   NaN
# 9991  9992  201.643310  172.168.1.44  10.10.10.22      UDP     214   NaN
# 9992  9993  201.663501  172.168.1.44  10.10.10.22      UDP     214   NaN
# 9993  9994  201.683663  172.168.1.44  10.10.10.22      UDP     214   NaN
# 9994  9995  201.703810  172.168.1.44  10.10.10.22      UDP     214   NaN
#
# [9995 rows x 7 columns]

# %%
mal_pcap2
# Out:
#        No.        Time        Source  Destination Protocol  Length  Info
# 0        1    0.000000  172.168.1.44  10.10.10.38      UDP     214   NaN
# 1        2    0.020185  172.168.1.44  10.10.10.38      UDP     214   NaN
# 2        3    0.040379  172.168.1.44  10.10.10.38      UDP     214   NaN
# 3        4    0.060614  172.168.1.44  10.10.10.38      UDP     214   NaN
# 4        5    0.080829  172.168.1.44  10.10.10.38      UDP     214   NaN
# ...    ...         ...           ...          ...      ...     ...   ...
# 9990  9991  201.629861  172.168.1.44  10.10.10.38      UDP     214   NaN
# 9991  9992  201.650034  172.168.1.44  10.10.10.38      UDP     214   NaN
# 9992  9993  201.670214  172.168.1.44  10.10.10.38      UDP     214   NaN
# 9993  9994  201.690399  172.168.1.44  10.10.10.38      UDP     214   NaN
# 9994  9995  201.710568  172.168.1.44  10.10.10.38      UDP     214   NaN
#
# [9995 rows x 7 columns]

# %%
from scapy.utils import PcapReader

# %%
pcap = PcapReader.read_packet(r"C:\Users\edenm\Documents\GitHub\VoIP-Research\Data\proccesed and tagged external datasets\RTP Flood records\malicious recordings\RTP_B_Host_Attacker\rtp.0.1.pcap")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-dbc89cfb5b9c> in <module>
# ----> 1 pcap = PcapReader.read_packet(r"C:\Users\edenm\Documents\GitHub\VoIP-Research\Data\proccesed and tagged external datasets\RTP Flood records\malicious recordings\RTP_B_Host_Attacker\rtp.0.1.pcap")
#
# ~\Anaconda3\lib\site-packages\scapy\utils.py in read_packet(self, size)
#    1347     def read_packet(self, size=MTU):
#    1348         # type: (int) -> Packet
# -> 1349         rp = super(PcapReader, self)._read_packet(size=size)
#    1350         if rp is None:
#    1351             raise EOFError
#
# TypeError: super(type, obj): obj must be an instance or subtype of type
